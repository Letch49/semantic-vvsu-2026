# %% [markdown]
# # Задача 3: Инвестиционный советник
#
# Специализированный агент для анализа акций и инвестиционных рекомендаций.
# Стек: `langchain` + `langchain-groq` + `FastAPI`.

# %%
# %pip install -q langchain langchain-groq langchain-community fastapi uvicorn python-dotenv pandas

# %% [markdown]
# ## 1. Инструменты агента

# %%
import os
import io
import pandas as pd
from langchain.tools import tool

STOCKS_CSV = """ticker,price,change_pct,sector
SBER,285.50,2.5,Финансы
GAZP,165.30,-1.2,Энергетика
YNDX,3789.90,3.1,Технологии
LKOH,7248.60,-2.8,Энергетика
GMKN,14520.50,1.5,Металлургия
ROSN,485.30,5.2,Энергетика
VTBR,0.312,-0.8,Финансы
MTSS,425.10,2.3,Телеком
"""


@tool
def get_stock_data(ticker: str) -> str:
    """Возвращает цену и изменение акции по тикеру (например SBER, GAZP)."""
    df = pd.read_csv(io.StringIO(STOCKS_CSV))
    row = df[df["ticker"] == ticker.upper()]
    if row.empty:
        return f"Тикер {ticker} не найден."
    r = row.iloc[0]
    return f"{r['ticker']}: цена {r['price']} руб., изменение {r['change_pct']}%, сектор: {r['sector']}"


@tool
def get_top_movers(direction: str = "up") -> str:
    """Возвращает топ-3 акций по росту (direction='up') или падению (direction='down')."""
    df = pd.read_csv(io.StringIO(STOCKS_CSV))
    if direction == "up":
        top = df.nlargest(3, "change_pct")[["ticker", "price", "change_pct"]]
        label = "Лидеры роста"
    else:
        top = df.nsmallest(3, "change_pct")[["ticker", "price", "change_pct"]]
        label = "Лидеры падения"
    return f"{label}:\n{top.to_string(index=False)}"


@tool
def get_sector_summary(sector: str) -> str:
    """Возвращает среднюю цену и изменение по сектору (Финансы, Энергетика, Технологии, ...)."""
    df = pd.read_csv(io.StringIO(STOCKS_CSV))
    filtered = df[df["sector"].str.lower() == sector.lower()]
    if filtered.empty:
        sectors = ", ".join(df["sector"].unique())
        return f"Сектор '{sector}' не найден. Доступные: {sectors}"
    tickers = ", ".join(filtered["ticker"])
    avg_price = filtered["price"].mean()
    avg_change = filtered["change_pct"].mean()
    return f"{sector}: [{tickers}], средняя цена {avg_price:.2f} руб., среднее изменение {avg_change:.2f}%"

# %% [markdown]
# ## 2. Агент

# %%
from langchain_groq import ChatGroq
from langchain.agents import AgentExecutor, create_tool_calling_agent
from langchain.prompts import ChatPromptTemplate, MessagesPlaceholder

SYSTEM_PROMPT = """Ты — профессиональный инвестиционный советник.
Помогаешь анализировать акции российского рынка и давать рекомендации: КУПИТЬ / ДЕРЖАТЬ / ПРОДАТЬ.
Используй инструменты для получения данных перед ответом.
Если вопрос не связан с инвестициями и акциями — ответь строго: "Команда неизвестна".
Отвечай кратко, на русском языке."""

llm = ChatGroq(
    model="llama3-8b-8192",
    temperature=0,
    api_key=os.getenv("GROQ_API_KEY"),
)

tools = [get_stock_data, get_top_movers, get_sector_summary]

prompt = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_PROMPT),
    MessagesPlaceholder("chat_history", optional=True),
    ("human", "{input}"),
    MessagesPlaceholder("agent_scratchpad"),
])

agent = create_tool_calling_agent(llm, tools, prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)

# %% [markdown]
# ## 3. Демо

# %%
def ask(question: str) -> str:
    return agent_executor.invoke({"input": question})["output"]


print(ask("Покажи данные по акции SBER"))
print()
print(ask("Какие акции сейчас растут больше всего?"))
print()
print(ask("Что происходит с энергетическим сектором?"))
print()
print(ask("Напиши стихотворение про осень"))

# %% [markdown]
# ## 4. FastAPI сервис
#
# Сохранить в `app.py` и запустить: `uvicorn app:app --reload`

# %%
from fastapi import FastAPI
from pydantic import BaseModel

app = FastAPI(title="Investment Advisor")


class ChatRequest(BaseModel):
    message: str
    session_id: str = "default"


class ChatResponse(BaseModel):
    response: str


@app.post("/generate", response_model=ChatResponse)
async def generate(req: ChatRequest):
    result = agent_executor.invoke({"input": req.message})
    return ChatResponse(response=result["output"])

# %% [markdown]
# ### Пример запроса
#
# ```bash
# curl -X POST http://localhost:8000/generate \
#      -H "Content-Type: application/json" \
#      -d '{"message": "Что происходит с энергетическим сектором?"}'
# ```
